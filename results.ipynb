# %%
import pandas as pd

# %%
pitchers = ['Kevin Gausman', 'Jordan Montgomery', 'Adrian Houser', 'Chris Flexen', 'Graham Ashcraft', 'Johnny Cueto', 
            'Dakota Hudson', 'Mackenzie Gore', 'Michael Lorenzen', 'Alex Faedo', 'Bailey Ober', 'Logan Allen', 
           'Quinn Priester', 'Max Fried', 'Cristian Javier', 'Mike Clevinger']
opponents = ['Cleveland', 'Oakland', 'Colorado', 'Milwaukee', 'Miami', 'Cincinnati', 'Tampa Bay', 'Philadelphia', 'Washington',
'Minnesota', 'Detroit', 'Toronto', 'Atlanta', 'Pittsburgh', 'Baltimore', 'New York (Yanks)']
model_pred = [6.82, 5.71, 3.36, 3.09, 3.96, 3.54, 2.15, 5.03, 3.73, 5.79, 5.41, 4.29, 3.85, 6.38, 4.53, 3.412] 
line = [5.5, 5, 4.5, 3.5, 3.5, 4.5,3.5,5.5, 3.5, 4.5, 5.5, 4.5, 3.5, 4.5, 4.5, 5.5]
bet = ["O", 'O', 'U', 'U', 'O', 'U', 'U', 'U', 'O', 'O', 'U', 'U', 'O', 'O', 'O', 'U']
K = [6,5, 5,4, 7,5, 2, 5, 5,5,9, 3,4,4,3,6]
hit = ["Y", 'Push', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y','Y', 'N', 'N', 'N']

# %%
results = pd.DataFrame({
    'name':pitchers,
    'opp':opponents,
    'pred':model_pred,
    'line':line,
    'bet':bet,
    'K':K,
    'Hit':hit})
results
# Out:
#                  name               opp   pred  line bet  K   Hit
# 0       Kevin Gausman         Cleveland  6.820   5.5   O  6     Y
# 1   Jordan Montgomery           Oakland  5.710   5.0   O  5  Push
# 2       Adrian Houser          Colorado  3.360   4.5   U  5     N
# 3        Chris Flexen         Milwaukee  3.090   3.5   U  4     N
# 4     Graham Ashcraft             Miami  3.960   3.5   O  7     Y
# 5        Johnny Cueto        Cincinnati  3.540   4.5   U  5     N
# 6       Dakota Hudson         Tampa Bay  2.150   3.5   U  2     Y
# 7      Mackenzie Gore      Philadelphia  5.030   5.5   U  5     Y
# 8    Michael Lorenzen        Washington  3.730   3.5   O  5     Y
# 9          Alex Faedo         Minnesota  5.790   4.5   O  5     Y
# 10        Bailey Ober           Detroit  5.410   5.5   U  9     N
# 11        Logan Allen           Toronto  4.290   4.5   U  3     Y
# 12     Quinn Priester           Atlanta  3.850   3.5   O  4     Y
# ...
